# %% [markdown]
# # Day 1 - AI Fundamentals Research
# **Date:5** June 22, 2026
# **Intern:** Fatima rasool
# **Topic:** What is Artificial Intelligence?

# %% [markdown]
# ## AI Research Comparison Table - Day 1
#
# | Concept | ChatGPT | Claude | Gemini | Article |
# |---------|---------|--------|--------|---------|
# | Definition | Machines mimicking humans | Human cognitive tasks | Simulating human thinking | Branch of CS |
# | History | Turing 1950, Dartmouth 1956 | Modern era focused | Deep Learning boom 2010s | Added AI Winters |
# | Narrow AI | One task only | No cross-domain | One job, can't go beyond | Zero outside capability |
# | General AI | Future concept | Not yet achieved | Still theoretical | Self-aware, futuristic |
# | Healthcare | Diagnosis, imaging | Drug prediction | Disease detection | MRI/X-ray analysis |
# | Finance | Fraud detection | Credit scoring | Risk assessment | Real-time flagging |
# | ML vs DL | ML learns, DL uses neural nets | DL is advanced ML | ML subset of AI | AI → ML → DL diagram |
# | Training | Learning from data | Model learns | Trained on datasets | High compute needed |
# | Inference | Making predictions | Applying knowledge | Model deployed | Single input, fast |
# | AI Engineer | Build and deploy | LLMs + agents | Design pipelines | RAG + fine-tuning |
#
# ## Best Source Per Topic
# | Topic | Winner | Reason |
# |-------|--------|--------|
# | Simplest explanation | ChatGPT | Beginner friendly |
# | Most unique info | Article | AI Winters concept |
# | Most practical | Claude | Engineering focused |
# | Most technical | Gemini | Technical details |

# %% [markdown]
# ## My Own Understanding (Synthesized)
#
# - AI = machines doing human-like tasks
# - Hierarchy: AI → ML → Deep Learning
# - Narrow AI = today | General AI = future
# - Training = teaching the model
# - Inference = model making predictions
# - AI Engineer 2026 = connects LLMs to real systems using RAG

# %% [markdown]
# ## References
#
# | # | Source | Date | Key Insight | link |
# |---|--------|------|-------------|------|
# | 1 | ChatGPT | June 22, 2026 | Simple AI breakdown for beginners |
# | 2 | Article | June 22, 2026 | AI Winters + Training/Inference table |https://www.researchgate.net/publication/389038943_Fundamentals_of_artificial_intelligence|
# | 3 | Claude | June 22, 2026 | AI Engineer role in 2026 |
# | 4 | Gemini | June 22, 2026 | Technical AI domains and applications |

# %%
print("Hi, this is Fatima Rasool, future AI Engineer!")
# Out:
# Hi, this is Fatima Rasool, future AI Engineer!
